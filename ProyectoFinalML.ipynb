# %% [markdown]
# <a href="https://colab.research.google.com/github/gomezan/inteligencia-artificial/blob/main/ProyectoFinalML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyecto final
#
# El objetivo del proyecto es realizar la segmentación de clientes de una tienda al por menor de regalos. Para ello se toma las ventas de la tienda entre el primero de diciembre de 2010 y el 9 de diciembre de 2011.

# %% [markdown]
# # Exploración de la información
# Se procede a importar el dataset con la información inicial del siguiente link:
#
# https://www.kaggle.com/hellbuoy/online-retail-customer-clustering
#
# Este cuenta con las siguientes características :
#
# *   Invoice No: Este es el número de la factura de la trasacción.
# *   Stock code: Este es el código en existencias del producto comprado.
# *   Description: Esta compuesto por el producto que se esta comprando en dicho pedido.
# *   Quantity: Cantidad o número de unidades compradas del producto.
# *   InvoceDate: Fecha donde se realiza la transacción.
# *   UnitPrice: Precio de una sola unidad del producto.
# *   CustomerID: Es un indicativo único por cada uno de los clientes.
# *   Country: País de origen del cliente que realiza la trasacción.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/retail/OnlineRetail.csv', sep=",", encoding="ISO-8859-1")
df.head(10)
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
# 5    536365     22752  ...    17850.0  United Kingdom
# 6    536365     21730  ...    17850.0  United Kingdom
# 7    536366     22633  ...    17850.0  United Kingdom
# 8    536366     22632  ...    17850.0  United Kingdom
# 9    536367     84879  ...    13047.0  United Kingdom
#
# [10 rows x 8 columns]

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# # Preparación de la información
#
# En esta sección se procesa la información del dataset en orden de poder realizar el agrupamiento sobre dicha información.

# %% [markdown]
# ## Limpieza y formato de la información
#
# En el presente se realiza el proceso de limpieza y se realizan conversiones de formato sobre la información para que esta sea más sencilla de manipular.
#
# En primer lugar, se eliminan las muestras que tenga información o casillas faltantes. Esta es el método más sencillo y se considera aceptable dado que se tiene un dataset con suficientes muestras.

# %%
tienda = df.dropna()
tienda.shape
# Out:
# (406829, 8)

# %% [markdown]
# Las características del ID del cliente y el número de factura se convierten a strings.

# %%
tienda.loc[:, ['CustomerID']] = tienda['CustomerID'].astype(str)
tienda.loc[:, ['InvoiceNo']] = tienda['InvoiceNo'].astype(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %% [markdown]
# Existen ciertas transacciones que manejan cantidades con valores negativos, se presumen que son devoluciones, dado que en este proyecto nos queremos concentrar en los clientes y sus ventas, estos valores son eliminados del dataset.

# %%
tienda = tienda[tienda['Quantity'] >= 0]

# %% [markdown]
# Finalmente, los países son convertidos de un string a un número que representa la etiqueta de dicho país.

# %%
tienda = tienda[tienda['Country'] != "Unspecified"]

# %%
formatPais=tienda.Country.unique()
DicCountry = dict(enumerate(formatPais, 0))
countryDic = {v: k for k, v in DicCountry.items()}

# %%
tienda=tienda.replace({'Country':countryDic})

# %% [markdown]
# El conjunto de datos despues del proceso de limpieza y formateo es igual a:

# %%
tienda.head(5)
# Out:
#   InvoiceNo StockCode  ... CustomerID  Country
# 0    536365    85123A  ...    17850.0        0
# 1    536365     71053  ...    17850.0        0
# 2    536365    84406B  ...    17850.0        0
# 3    536365    84029G  ...    17850.0        0
# 4    536365    84029E  ...    17850.0        0
#
# [5 rows x 8 columns]

# %% [markdown]
# ## Construcción de la información
#
# En esta sección se obtienen las características necesarias para realizar el agrupamiento de la información. Las características deseadas se obtienen de las características del dataset de limpieza y formateo.
#
# Las características deseadas son:
#
# *   Recencia: Corresponde a la última vez que el cliente tuvo contacto con la tienda.
# *   Frecuencia: Este es el número de veces que el cliente ha tenido contacto con la tienda.
# *   Dinero: Cantidad de dinero que ha gastado el cliente en la tienda.
# *   País de origen: Este es el país donde reside el cliente en el momento de realizar la transacción.
# *   Tipo de producto: Los productos se divide en tres categorías, se revisa cuál de los tres tipos es el que el cliente realiza mayor cantidad de pedidos.
# *   Número de productos: Este es el número neto de productos que el cliente ha comparado.

# %% [markdown]
# ### Dinero

# %%
tienda.loc[:, ['Total']] = tienda['Quantity']*tienda['UnitPrice']
dinero= tienda.groupby('CustomerID')['Total'].sum()
dinero = dinero.reset_index()
dinero.head()
dinero.shape
# Out:
# (4335, 2)

# %% [markdown]
# ### Frecuencia

# %%
frecuencia = tienda.groupby('CustomerID')['InvoiceNo'].count()
frecuencia = frecuencia.reset_index()
frecuencia.columns = ['CustomerID', 'Frecuencia']
frecuencia.head()
# Out:
#   CustomerID  Frecuencia
# 0    12346.0           1
# 1    12347.0         182
# 2    12348.0          31
# 3    12349.0          73
# 4    12350.0          17

# %% [markdown]
# ### Recencia
#
# Se modifica el formato en orden de facilitar la visualización de la fecha.

# %%
tienda.loc[:, ['InvoiceDate']] = pd.to_datetime(tienda['InvoiceDate'],format='%d-%m-%Y %H:%M')

# %% [markdown]
# Se emplea la última fecha como la fecha de referencia dado que las fechas presentes en el dataset distan bastante en dias respecto a la fecha presente.

# %%
ultimo = max(tienda['InvoiceDate'])
print(ultimo)
tienda.loc[:, ['Diff']] = ultimo - tienda['InvoiceDate']
tienda.head()
# Out:
# 2011-12-09 12:50:00
#   InvoiceNo StockCode  ...  Total              Diff
# 0    536365    85123A  ...  15.30 373 days 04:24:00
# 1    536365     71053  ...  20.34 373 days 04:24:00
# 2    536365    84406B  ...  22.00 373 days 04:24:00
# 3    536365    84029G  ...  20.34 373 days 04:24:00
# 4    536365    84029E  ...  20.34 373 days 04:24:00
#
# [5 rows x 10 columns]

# %%
recencia = tienda.groupby('CustomerID')['Diff'].min().dt.days
recencia = recencia.reset_index()
recencia.head()
# Out:
#   CustomerID  Diff
# 0    12346.0   325
# 1    12347.0     1
# 2    12348.0    74
# 3    12349.0    18
# 4    12350.0   309

# %% [markdown]
# ### País de origen
#
# La mayoría de los clientes solo realizan compras desde un único pais por lo que se procede a eliminar los duplicados para obtener el país en el cual reside cada cliente.

# %%
pais=tienda[['CustomerID','Country']].drop_duplicates()
pais = pais.sort_values('CustomerID')

# %% [markdown]
# Existe un número muy bajo de clientes que realiza compras desde más de un país. Dado que este no es el comportamiento típico y dado que solo son dos países, por simplicidad se procede a eliminar un país extra de los disponibles.

# %%
pais.groupby('CustomerID').size().loc[lambda x: x>1]
# Out:
# CustomerID
# 12370.0    2
# 12394.0    2
# 12417.0    2
# 12422.0    2
# 12429.0    2
# 12431.0    2
# 12455.0    2
# 12457.0    2
# dtype: int64

# %%
pais=pais.drop_duplicates(subset=['CustomerID'])
pais=pais.reset_index(drop=True)
pais.head(5)
# Out:
#   CustomerID  Country
# 0    12346.0        0
# 1    12347.0       15
# 2    12348.0       20
# 3    12349.0       11
# 4    12350.0        5

# %% [markdown]
# ### Productos
#
# Los productos se dividen de acuerdo a la popularidad de compra de cada uno. Existen tres categorías:
#
# *   Populares: Son los productos que mayores unidades vendidas se registra.
# *   Medio: Productos con ventas por unidad moderadas.
# *   Bajo: Son los productos que menos ventas por unidad se registran.
#
# Dadas estas categorías se almacena el tipo de productos que más frecuentemente solicita en sus compras.

# %%
tipos = pd.DataFrame(tienda.groupby('Description')['Quantity'].sum())
tipos=tipos.sort_values('Quantity')
tipos = tipos.reset_index()
tipos.head(10)
tipos.shape
# Out:
# (3877, 2)

# %%
bajo=tipos[tipos['Quantity'] <=100]
print(bajo.shape)
populares=tipos[tipos['Quantity'] >=1000]
print(populares.shape)
medio = tipos[~tipos.Quantity.isin(bajo.Quantity) & ~tipos.Quantity.isin(populares.Quantity)]
print(medio.shape)
# Out:
# (1240, 2)
# (1189, 2)
# (1448, 2)

# %%
tienda.loc[:, ['Product_type']]=0
tienda.loc[tienda.Description.isin(medio.Description), 'Product_type'] = 1
tienda.loc[tienda.Description.isin(populares.Description), 'Product_type'] = 2
tienda.head(10)
# Out:
#   InvoiceNo StockCode  ...              Diff  Product_type
# 0    536365    85123A  ... 373 days 04:24:00             2
# 1    536365     71053  ... 373 days 04:24:00             2
# 2    536365    84406B  ... 373 days 04:24:00             2
# 3    536365    84029G  ... 373 days 04:24:00             2
# 4    536365    84029E  ... 373 days 04:24:00             2
# 5    536365     22752  ... 373 days 04:24:00             2
# 6    536365     21730  ... 373 days 04:24:00             1
# 7    536366     22633  ... 373 days 04:22:00             2
# 8    536366     22632  ... 373 days 04:22:00             1
# 9    536367     84879  ... 373 days 04:16:00             2
#
# [10 rows x 11 columns]

# %%
tipoProducto = tienda.groupby('CustomerID')['Product_type'].mean().apply(np.round)
tipoProducto = tipoProducto.reset_index()
tipoProducto.head()
# Out:
#   CustomerID  Product_type
# 0    12346.0           2.0
# 1    12347.0           2.0
# 2    12348.0           2.0
# 3    12349.0           2.0
# 4    12350.0           1.0

# %% [markdown]
# ### Totalidad de productos comprados

# %%
producto = tienda.groupby('CustomerID')['Quantity'].sum()
producto = producto.reset_index()
producto.head()
# Out:
#   CustomerID  Quantity
# 0    12346.0     74215
# 1    12347.0      2458
# 2    12348.0      2341
# 3    12349.0       631
# 4    12350.0       197

# %% [markdown]
# ## Fusión de la información
#
# En esta sección se procede a unir la información a la que se aplicará el algoritmo de agrupamiento.

# %%
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
datos=frecuencia
datos.loc[:,['Recencia']]=recencia.Diff
datos.loc[:,['Dinero']]=dinero.Total
datos.loc[:,['Pais']]=pais.Country
datos.loc[:,['Tipo']]=tipoProducto.Product_type
datos.loc[:,['Productos']]=producto.Quantity
datos.head()
# Out:
#   CustomerID  Frecuencia  Recencia    Dinero  Pais  Tipo  Productos
# 0    12346.0           1       325  77183.60     0   2.0      74215
# 1    12347.0         182         1   4310.00    15   2.0       2458
# 2    12348.0          31        74   1797.24    20   2.0       2341
# 3    12349.0          73        18   1757.55    11   2.0        631
# 4    12350.0          17       309    334.40     5   1.0        197

# %%
attributes = ['Frecuencia','Recencia','Dinero','Pais','Tipo','Productos']
X= datos[attributes]

# %% [markdown]
# Se observa dado la siguiente gráfica que es necesario escalizar la información. A continuación se presenta el patrón obtenido por la información luego de emplear 3 escalizadores diferentes.

# %%
plt.rcParams['figure.figsize'] = [10,8]
sns.boxplot(data =X, orient="v", palette="Set2" ,whis=1.5,saturation=1, width=0.7)
plt.title("Distribución", fontsize = 14, fontweight = 'bold')
plt.ylabel("Rango", fontweight = 'bold')
plt.xlabel("Atributos", fontweight = 'bold')
# Out:
# Text(0.5, 0, 'Atributos')

# %% [markdown]
# ### Escalizador Robusto

# %%
robust = RobustScaler().fit(X)
xr=robust.transform(X)

# %%
visual = PCA(2)  
model = visual.fit(xr)
projected = model.transform(xr)
print("varianza explicada")
print(visual.explained_variance_ratio_)
plt.scatter(projected[:, 0], projected[:, 1],alpha=0.5)
plt.xlabel('componente 1')
plt.ylabel('componente 2')
# Out:
# varianza explicada
# [0.78119672 0.12110745]
# Text(0, 0.5, 'componente 2')

# %%
plt.rcParams['figure.figsize'] = [10,8]
sns.boxplot(data =xr, orient="v", palette="Set2" ,whis=1.5,saturation=1, width=0.7)
plt.title("Distribución", fontsize = 14, fontweight = 'bold')
plt.ylabel("Rango", fontweight = 'bold')
plt.xlabel("Atributos", fontweight = 'bold')
# Out:
# Text(0.5, 0, 'Atributos')

# %% [markdown]
# ### Escalizador estándar

# %%
standar = StandardScaler()
standar.fit(X)
xe=standar.transform(X)

# %%
visual = PCA(2)  
model = visual.fit(xe)
projected = model.transform(xe)
print("varianza explicada")
print(visual.explained_variance_ratio_)
plt.scatter(projected[:, 0], projected[:, 1],alpha=0.5)
plt.xlabel('componente 1')
plt.ylabel('componente 2')
# Out:
# varianza explicada
# [0.38063521 0.19577893]
# Text(0, 0.5, 'componente 2')

# %%
plt.rcParams['figure.figsize'] = [10,8]
sns.boxplot(data =xe, orient="v", palette="Set2" ,whis=1.5,saturation=1, width=0.7)
plt.title("Distribución", fontsize = 14, fontweight = 'bold')
plt.ylabel("Rango", fontweight = 'bold')
plt.xlabel("Atributos", fontweight = 'bold')
# Out:
# Text(0.5, 0, 'Atributos')

# %% [markdown]
# ### Escalizador Min -Max

# %%
minMax = MinMaxScaler()
minMax.fit(X)
xm=minMax.transform(X)

# %%
visual = PCA(2)  
model = visual.fit(xm)
projected = model.transform(xm)
print("varianza explicada")
print(visual.explained_variance_ratio_)
plt.scatter(projected[:, 0], projected[:, 1],alpha=0.5)
plt.xlabel('componente 1')
plt.ylabel('componente 2')
# Out:
# varianza explicada
# [0.65122898 0.23891397]
# Text(0, 0.5, 'componente 2')

# %%
plt.rcParams['figure.figsize'] = [10,8]
sns.boxplot(data =xm, orient="v", palette="Set2" ,whis=1.5,saturation=1, width=0.7)
plt.title("Distribución", fontsize = 14, fontweight = 'bold')
plt.ylabel("Rango", fontweight = 'bold')
plt.xlabel("Atributos", fontweight = 'bold')
# Out:
# Text(0.5, 0, 'Atributos')

# %% [markdown]
# # Análisis de dimensionalidad
# Además de los diferentes patrones obtenidos de la escalización, también se observa que este tiene un efecto sobre la varianza explicada de la información. Como se puede observar en la gráfica a continuación, los escalizadores Min-max y Robusto conservan mayor variabilidad en menos componentes, mientras el Estándar necesita de cerca de 4 componentes para alcanzar una variabilidad de más del 90%.

# %%
pcam = PCA(n_components=6)
pcam.fit(xm)
pcar = PCA(n_components=6)
pcar.fit(xr)
pcae = PCA(n_components=6)
pcae.fit(xe)
# Out:
# PCA(n_components=6)

# %%
fig, ax = plt.subplots()
ax.plot(np.cumsum(pcam.explained_variance_ratio_), label = 'Min-Max')
ax.plot(np.cumsum(pcar.explained_variance_ratio_), label = 'Robusto')
ax.plot(np.cumsum(pcae.explained_variance_ratio_), label = 'Estándar')
ax.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# Dados los diferentes patrones e impacto que se tiene sobre la variabilidad, se considera necesario probar con los diferentes escalizadores mencionados.
# Se prepara información para lograr realizar pruebas sobre los escalizadores en el entrenamiento de los modelos.

# %%
pca = PCA(n_components=4)
pca.fit(xm)
x4m = pca.transform(xm)
pca.fit(xr)
x4r = pca.transform(xr)
pca.fit(xe)
x4e = pca.transform(xe)

# %%
pca = PCA(n_components=3)
pca.fit(xr)
x3m = pca.transform(xm)
pca.fit(xr)
x3r = pca.transform(xr)
pca.fit(xe)
x3e = pca.transform(xe)

# %%
pca = PCA(n_components=2)
pca.fit(xr)
x2m = pca.transform(xm)
pca.fit(xr)
x2r = pca.transform(xr)
pca.fit(xe)
x2e = pca.transform(xe)

# %% [markdown]
# # Entrenamiento
#
# Dentro del entrenamiento fue empleado el puntaje de silueta, pero dado a que no se conseguían buenos resultados con esta, se decidió emplear otras métricas según el método utilizado.

# %%
from sklearn.metrics import silhouette_score

# %% [markdown]
# ## HDBSCAN
# Con base en los resultados de la sección anterior se propone un algoritmo de densidad de muestras llamado HBDSCAN. Se instancian las dependencias y se realiza el barrido de hiperparámetros, escalizadores y componentes de PCA.
#
# La métrica empleada para medir los clusters es el Density Based Clustering Validation o DBCV. Esta es una métrica de densidad que tiene como ventaja, en comparación a la silueta, la capacidad de tener en cuenta el ruido de la información.

# %%
! pip install -U hdbscan
# Out:
# Collecting hdbscan
#   Downloading hdbscan-0.8.27.tar.gz (6.4 MB)
#      |████████████████████████████████| 6.4 MB 4.2 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.7/dist-packages (from hdbscan) (1.0.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan) (1.1.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from hdbscan) (1.19.5)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.7/dist-packages (from hdbscan) (0.29.24)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from hdbscan) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20->hdbscan) (3.0.0)
# Building wheels for collected packages: hdbscan
#   Building wheel for hdbscan (PEP 517) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.27-cp37-cp37m-linux_x86_64.whl size=2311866 sha256=355e39eb090252234389410b379f7d9291ceae42a4446f16520a48915d7120f8
#   Stored in directory: /root/.cache/pip/wheels/73/5f/2f/9a259b84003b84847c259779206acecabb25ab56f1506ee72b
# Successfully built hdbscan
# Installing collected packages: hdbscan
# Successfully installed hdbscan-0.8.27

# %%
import hdbscan

# %%
min_sample = [1,3,10,30,60,99]
min_cluster = [3,10,30,100,300]
epsilon=[0.1,0.2,0.5,1]
alpha=[0.1,0.2,0.5,0.99]

tam_sample=len(min_sample)
tam_cluster=len(min_cluster)
tam_epsilon=len(epsilon)
tam_alpha=len(alpha)

res_sample=[0 for i in range (tam_sample) ]
res_cluster=[0 for j in range (tam_cluster) ]
res_epsilon=[0 for k in range (tam_epsilon) ]
res_alpha=[0 for l in range (tam_alpha)]

res_total=[]

for i in  range (tam_sample):
  for j in range (tam_cluster):
    for k in range (tam_epsilon):
      for l in range (tam_alpha):
    
        #calular score
        hc= hdbscan.HDBSCAN(gen_min_span_tree=True,min_cluster_size=min_cluster[j],min_samples=min_sample[i],cluster_selection_epsilon=epsilon[k],alpha=alpha[l])
        hc.fit(x4m)
        #Guardar resultados
        res=silueta=hc.relative_validity_
        res_sample[i]=res_sample[i]+res
        res_cluster[j]=res_cluster[j]+res
        res_epsilon[k]=res_epsilon[k]+res
        res_alpha[l]=res_alpha[l]+res
        res_total.append(res)
        #imprimir
        print("sample: ",min_sample[i]," ,cluster: ",min_cluster[j]," ,epsilon: ",epsilon[k]," ,alpha: ",alpha[l]," ,score: ",res)

array_sample = np.array(res_sample)
array_cluster = np.array(res_cluster)
array_epsilon = np.array(res_epsilon)
array_alpha = np.array(res_alpha)

array_sample=array_sample/(tam_cluster*tam_epsilon*tam_alpha)
array_cluster=array_cluster/(tam_sample*tam_epsilon*tam_alpha)
array_epsilon=array_epsilon/(tam_cluster*tam_sample*tam_alpha)
array_alpha=array_alpha/(tam_sample*tam_epsilon*tam_cluster)

print("El promedio es igual a : ")
mean=np.mean(np.array(res_total))
print(mean)
# Out:
# sample:  1  ,cluster:  3  ,epsilon:  0.1  ,alpha:  0.1  ,score:  0
,cluster:  3  ,epsilon:  0.1  ,alpha:  0.1  ,score:  0.048900844922651086
# sample:  30  ,cluster:  3  ,epsilon:  0.1  ,alpha:  0.2  ,score:  0.048900844922651086
# sample:  30  ,cluster:  3  ,epsilon:  0.1  ,alpha:  0.5  ,score:  0.048900844922651086
# sample:  30  ,cluster:  3  ,epsilon:  0.1  ,alpha:  0.99  ,score:  0.048900844922651086
# sample:  30  ,cluster:  3  ,epsilon:  0.2  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  3  ,epsilon:  0.2  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  3  ,epsilon:  0.2  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  3  ,epsilon:  0.2  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  3  ,epsilon:  0.5  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  3  ,epsilon:  0.5  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  3  ,epsilon:  0.5  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  3  ,epsilon:  0.5  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  3  ,epsilon:  1  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  3  ,epsilon:  1  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  3  ,epsilon:  1  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  3  ,epsilon:  1  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  10  ,epsilon:  0.1  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  10  ,epsilon:  0.1  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  10  ,epsilon:  0.1  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  10  ,epsilon:  0.1  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  10  ,epsilon:  0.2  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  10  ,epsilon:  0.2  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  10  ,epsilon:  0.2  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  10  ,epsilon:  0.2  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  10  ,epsilon:  0.5  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  10  ,epsilon:  0.5  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  10  ,epsilon:  0.5  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  10  ,epsilon:  0.5  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  10  ,epsilon:  1  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  10  ,epsilon:  1  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  10  ,epsilon:  1  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  10  ,epsilon:  1  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  30  ,epsilon:  0.1  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  30  ,epsilon:  0.1  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  30  ,epsilon:  0.1  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  30  ,epsilon:  0.1  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  30  ,epsilon:  0.2  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  30  ,epsilon:  0.2  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  30  ,epsilon:  0.2  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  30  ,epsilon:  0.2  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  30  ,epsilon:  0.5  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  30  ,epsilon:  0.5  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  30  ,epsilon:  0.5  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  30  ,epsilon:  0.5  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  30  ,epsilon:  1  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  30  ,epsilon:  1  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  30  ,epsilon:  1  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  30  ,epsilon:  1  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  100  ,epsilon:  0.1  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  100  ,epsilon:  0.1  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  100  ,epsilon:  0.1  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  100  ,epsilon:  0.1  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  100  ,epsilon:  0.2  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  100  ,epsilon:  0.2  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  100  ,epsilon:  0.2  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  100  ,epsilon:  0.2  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  100  ,epsilon:  0.5  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  100  ,epsilon:  0.5  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  100  ,epsilon:  0.5  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  100  ,epsilon:  0.5  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  100  ,epsilon:  1  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  100  ,epsilon:  1  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  100  ,epsilon:  1  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  100  ,epsilon:  1  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  300  ,epsilon:  0.1  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  300  ,epsilon:  0.1  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  300  ,epsilon:  0.1  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  300  ,epsilon:  0.1  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  300  ,epsilon:  0.2  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  300  ,epsilon:  0.2  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  300  ,epsilon:  0.2  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  300  ,epsilon:  0.2  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  300  ,epsilon:  0.5  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  300  ,epsilon:  0.5  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  300  ,epsilon:  0.5  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  300  ,epsilon:  0.5  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  30  ,cluster:  300  ,epsilon:  1  ,alpha:  0.1  ,score:  0.019957258530985608
# sample:  30  ,cluster:  300  ,epsilon:  1  ,alpha:  0.2  ,score:  0.019957258530985608
# sample:  30  ,cluster:  300  ,epsilon:  1  ,alpha:  0.5  ,score:  0.019957258530985608
# sample:  30  ,cluster:  300  ,epsilon:  1  ,alpha:  0.99  ,score:  0.019957258530985608
# sample:  60  ,cluster:  3  ,epsilon:  0.1  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  3  ,epsilon:  0.1  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  3  ,epsilon:  0.1  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  3  ,epsilon:  0.1  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  60  ,cluster:  3  ,epsilon:  0.2  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  3  ,epsilon:  0.2  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  3  ,epsilon:  0.2  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  3  ,epsilon:  0.2  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  60  ,cluster:  3  ,epsilon:  0.5  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  3  ,epsilon:  0.5  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  3  ,epsilon:  0.5  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  3  ,epsilon:  0.5  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  60  ,cluster:  3  ,epsilon:  1  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  3  ,epsilon:  1  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  3  ,epsilon:  1  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  3  ,epsilon:  1  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  60  ,cluster:  10  ,epsilon:  0.1  ,alpha:  0.1  ,score:  0.018215484403983354
# sample:  60  ,cluster:  10  ,epsilon:  0.1  ,alpha:  0.2  ,score:  0.018215484403983354
# sample:  60  ,cluster:  10  ,epsilon:  0.1  ,alpha:  0.5  ,score:  0.018215484403983354
# sample:  60  ,cluster:  10  ,epsilon:  0.1  ,alpha:  0.99  ,score:  0.018215484403983354
# sample:  60  ,cluster:  10  ,epsilon:  0.2  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  10  ,epsilon:  0.2  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  10  ,epsilon:  0.2  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  10  ,epsilon:  0.2  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  60  ,cluster:  10  ,epsilon:  0.5  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  10  ,epsilon:  0.5  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  10  ,epsilon:  0.5  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  10  ,epsilon:  0.5  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  60  ,cluster:  10  ,epsilon:  1  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  10  ,epsilon:  1  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  10  ,epsilon:  1  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  10  ,epsilon:  1  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  60  ,cluster:  30  ,epsilon:  0.1  ,alpha:  0.1  ,score:  0.018215484403983354
# sample:  60  ,cluster:  30  ,epsilon:  0.1  ,alpha:  0.2  ,score:  0.018215484403983354
# sample:  60  ,cluster:  30  ,epsilon:  0.1  ,alpha:  0.5  ,score:  0.018215484403983354
# sample:  60  ,cluster:  30  ,epsilon:  0.1  ,alpha:  0.99  ,score:  0.018215484403983354
# sample:  60  ,cluster:  30  ,epsilon:  0.2  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  30  ,epsilon:  0.2  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  30  ,epsilon:  0.2  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  30  ,epsilon:  0.2  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  60  ,cluster:  30  ,epsilon:  0.5  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  30  ,epsilon:  0.5  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  30  ,epsilon:  0.5  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  30  ,epsilon:  0.5  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  60  ,cluster:  30  ,epsilon:  1  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  30  ,epsilon:  1  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  30  ,epsilon:  1  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  30  ,epsilon:  1  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  60  ,cluster:  100  ,epsilon:  0.1  ,alpha:  0.1  ,score:  0.018215484403983354
# sample:  60  ,cluster:  100  ,epsilon:  0.1  ,alpha:  0.2  ,score:  0.018215484403983354
# sample:  60  ,cluster:  100  ,epsilon:  0.1  ,alpha:  0.5  ,score:  0.018215484403983354
# sample:  60  ,cluster:  100  ,epsilon:  0.1  ,alpha:  0.99  ,score:  0.018215484403983354
# sample:  60  ,cluster:  100  ,epsilon:  0.2  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  100  ,epsilon:  0.2  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  100  ,epsilon:  0.2  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  100  ,epsilon:  0.2  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  60  ,cluster:  100  ,epsilon:  0.5  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  100  ,epsilon:  0.5  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  100  ,epsilon:  0.5  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  100  ,epsilon:  0.5  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  60  ,cluster:  100  ,epsilon:  1  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  100  ,epsilon:  1  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  100  ,epsilon:  1  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  100  ,epsilon:  1  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  60  ,cluster:  300  ,epsilon:  0.1  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  300  ,epsilon:  0.1  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  300  ,epsilon:  0.1  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  300  ,epsilon:  0.1  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  60  ,cluster:  300  ,epsilon:  0.2  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  300  ,epsilon:  0.2  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  300  ,epsilon:  0.2  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  300  ,epsilon:  0.2  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  60  ,cluster:  300  ,epsilon:  0.5  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  300  ,epsilon:  0.5  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  300  ,epsilon:  0.5  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  300  ,epsilon:  0.5  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  60  ,cluster:  300  ,epsilon:  1  ,alpha:  0.1  ,score:  0.02232276801833418
# sample:  60  ,cluster:  300  ,epsilon:  1  ,alpha:  0.2  ,score:  0.02232276801833418
# sample:  60  ,cluster:  300  ,epsilon:  1  ,alpha:  0.5  ,score:  0.02232276801833418
# sample:  60  ,cluster:  300  ,epsilon:  1  ,alpha:  0.99  ,score:  0.02232276801833418
# sample:  99  ,cluster:  3  ,epsilon:  0.1  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  3  ,epsilon:  0.1  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  3  ,epsilon:  0.1  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  3  ,epsilon:  0.1  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  3  ,epsilon:  0.2  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  3  ,epsilon:  0.2  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  3  ,epsilon:  0.2  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  3  ,epsilon:  0.2  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  3  ,epsilon:  0.5  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  3  ,epsilon:  0.5  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  3  ,epsilon:  0.5  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  3  ,epsilon:  0.5  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  3  ,epsilon:  1  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  3  ,epsilon:  1  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  3  ,epsilon:  1  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  3  ,epsilon:  1  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  10  ,epsilon:  0.1  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  10  ,epsilon:  0.1  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  10  ,epsilon:  0.1  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  10  ,epsilon:  0.1  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  10  ,epsilon:  0.2  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  10  ,epsilon:  0.2  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  10  ,epsilon:  0.2  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  10  ,epsilon:  0.2  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  10  ,epsilon:  0.5  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  10  ,epsilon:  0.5  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  10  ,epsilon:  0.5  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  10  ,epsilon:  0.5  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  10  ,epsilon:  1  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  10  ,epsilon:  1  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  10  ,epsilon:  1  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  10  ,epsilon:  1  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  30  ,epsilon:  0.1  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  30  ,epsilon:  0.1  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  30  ,epsilon:  0.1  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  30  ,epsilon:  0.1  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  30  ,epsilon:  0.2  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  30  ,epsilon:  0.2  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  30  ,epsilon:  0.2  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  30  ,epsilon:  0.2  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  30  ,epsilon:  0.5  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  30  ,epsilon:  0.5  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  30  ,epsilon:  0.5  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  30  ,epsilon:  0.5  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  30  ,epsilon:  1  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  30  ,epsilon:  1  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  30  ,epsilon:  1  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  30  ,epsilon:  1  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  100  ,epsilon:  0.1  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  100  ,epsilon:  0.1  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  100  ,epsilon:  0.1  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  100  ,epsilon:  0.1  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  100  ,epsilon:  0.2  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  100  ,epsilon:  0.2  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  100  ,epsilon:  0.2  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  100  ,epsilon:  0.2  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  100  ,epsilon:  0.5  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  100  ,epsilon:  0.5  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  100  ,epsilon:  0.5  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  100  ,epsilon:  0.5  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  100  ,epsilon:  1  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  100  ,epsilon:  1  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  100  ,epsilon:  1  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  100  ,epsilon:  1  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  300  ,epsilon:  0.1  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  300  ,epsilon:  0.1  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  300  ,epsilon:  0.1  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  300  ,epsilon:  0.1  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  300  ,epsilon:  0.2  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  300  ,epsilon:  0.2  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  300  ,epsilon:  0.2  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  300  ,epsilon:  0.2  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  300  ,epsilon:  0.5  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  300  ,epsilon:  0.5  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  300  ,epsilon:  0.5  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  300  ,epsilon:  0.5  ,alpha:  0.99  ,score:  0.019109773347728218
# sample:  99  ,cluster:  300  ,epsilon:  1  ,alpha:  0.1  ,score:  0.019109773347728218
# sample:  99  ,cluster:  300  ,epsilon:  1  ,alpha:  0.2  ,score:  0.019109773347728218
# sample:  99  ,cluster:  300  ,epsilon:  1  ,alpha:  0.5  ,score:  0.019109773347728218
# sample:  99  ,cluster:  300  ,epsilon:  1  ,alpha:  0.99  ,score:  0.019109773347728218
# El promedio es igual a :
# 0.05439602596715168

# %% [markdown]
# Después de realizar el barrido de hiperparámetros, escalizadores y componentes de PCA el mejor resultado se presenta a continuación. Este cuenta con una reducción dimensional de 4 componentes y emplea el escalizador Min-Max.

# %%
hc= hdbscan.HDBSCAN(min_cluster_size=10,min_samples=3,cluster_selection_epsilon=0.1,alpha=0.5, gen_min_span_tree=True)
hc.fit(x4m)
labelshc=hc.labels_
print("Silueta")
print(silhouette_score(x4m, labelshc, metric='euclidean'))
print("# clusters")
print(hc.labels_.max())
hc.relative_validity_
# Out:
# Silueta
# 0.5437057757886606
# # clusters
# 2
# 0.21897477024999606

# %% [markdown]
# La conclusión del algoritmo es que existen 3 clusters, los cuales concuerdan exactamente con la imagen mostrada a continuación. Esta es la solución más obvia y fácilmente comprobable a obtener.

# %%
pd.Series(hc.labels_).value_counts()
# Out:
#  2    3837
#  1     473
#  0      24
# -1       1
# dtype: int64

# %%
plt.scatter(projected[:, 0], projected[:, 1],alpha=0.5,c=labelshc)
plt.xlabel('componente 1')
plt.ylabel('componente 2')
# Out:
# Text(0, 0.5, 'componente 2')

# %% [markdown]
# A continuación se presenta el árbol condensado que permite observar la jerarquía formada por el algoritmo. Dada la complejidad de las ramificaciones apenas es posible distinguir las 3 ramas que forman los 3 clusters encontrados.

# %%
hc.condensed_tree_.plot(log_size=True)

# %% [markdown]
# ## GMM
#
# Se propone un método paramétrico conocido como  GMM, se espera que este pueda caracterizar las funciones de probabilidad que rigen la información y así encontrar los clusters de esta.
#
# Al igual que en HDBSCAN se procede a realizar un barrido de hiperperámetros, componentes de PCA y escalizadores.
#
# Las métricas usadas para realizar el barrido son el Akaike information criterion o AIC y el Bayesian information criterion o BIC. Ambas métricas están íntimamente relacionadas, estas son métricas basadas en los cálculos probabilísticos derivados de GMM y son métricas de minimización. Valores bajos de estos se asocian  con menor incertidumbre y menor perdida de información.

# %%
from sklearn.mixture import GaussianMixture

# %%
n_componentes = [2,5,10,20,50,100]
tipo = ['full', 'tied', 'diag', 'spherical']
random=[1,3,10,30,100]

res_totalAIC=[]
res_totalBIC=[]

#Tamaños
tam_componentes=len(n_componentes)
tam_tipo=len(tipo)
tam_random=len(random)

#almacen de respuestas
res_componentesAIC=[0 for i in range (tam_componentes) ]
res_tipoAIC=[0 for j in range (tam_tipo) ]
res_randomAIC=[0 for k in range (tam_random) ]
res_componentesBIC=[0 for i in range (tam_componentes) ]
res_tipoBIC=[0 for j in range (tam_tipo) ]
res_randomBIC=[0 for k in range (tam_random) ]


for i in  range (tam_componentes):
  for j in range (tam_tipo):
    for k in range (tam_random):
    
        #calular score
        gm = GaussianMixture(n_components=n_componentes[i], random_state=random[k], covariance_type=tipo[j]).fit(xm)
        labels=gm.predict(xm)

        #Guardar resultados
        resAIC=gm.aic(xm)
        resBIC=gm.bic(xm)
        res_totalAIC.append(resAIC)
        res_totalBIC.append(resBIC)
        res_componentesAIC[i]=res_componentesAIC[i]+resAIC
        res_tipoAIC[j]=res_tipoAIC[j]+resAIC
        res_randomAIC[k]=res_randomAIC[k]+resAIC
        res_componentesBIC[i]=res_componentesBIC[i]+resBIC
        res_tipoBIC[j]=res_tipoBIC[j]+resBIC
        res_randomBIC[k]=res_randomBIC[k]+resBIC
        #imprimir
        print("componente: ",n_componentes[i]," ,tipo: ",tipo[j]," ,random: ",random[k]," ,AIC: ",resAIC," ,BIC: ",resBIC)

array_componentesAIC = np.array(res_componentesAIC)
array_tipoAIC = np.array(res_tipoAIC)
array_randomAIC = np.array(res_randomAIC)
array_componentesBIC = np.array(res_componentesBIC)
array_tipoBIC = np.array(res_tipoBIC)
array_randomBIC = np.array(res_randomBIC)

array_componentesAIC=array_componentesAIC/(len(array_componentesAIC))
array_tipoAIC=array_tipoAIC/(len(array_tipoAIC))
array_randomAIC=array_randomAIC/(len(array_randomAIC))
array_componentesBIC=array_componentesBIC/(len(array_componentesBIC))
array_tipoBIC=array_tipoBIC/(len(array_tipoBIC))
array_randomBIC=array_randomBIC/(len(array_randomBIC))

print("El promedio es igual a : ")
mean=np.mean(np.array(res_totalAIC))
print("AIC: ")
print(mean)
mean=np.mean(np.array(res_totalBIC))
print("BIC: ")
print(mean)
# Out:
# componente:  2  ,tipo:  full  ,random:  1  ,AIC:  -144509.77974003396  ,BIC:  -144159.18351112716
# componente:  2  ,tipo:  full  ,random:  3  ,AIC:  -116803.36201923987  ,BIC:  -116452.76579033305
# componente:  2  ,tipo:  full  ,random:  10  ,AIC:  -116786.6821937187  ,BIC:  -116436.0859648119
# componente:  2  ,tipo:  full  ,random:  30  ,AIC:  -116786.6821937187  ,BIC:  -116436.0859648119
# componente:  2  ,tipo:  full  ,random:  100  ,AIC:  -116786.6821937187  ,BIC:  -116436.0859648119
# componente:  2  ,tipo:  tied  ,random:  1  ,AIC:  -79980.42072107365  ,BIC:  -79763.68850684035
# componente:  100  ,tipo:  spherical  ,random:  10  ,AIC:  -155204.77102866926  ,BIC:  -150111.56399418676
# componente:  100  ,tipo:  spherical  ,random:  30  ,AIC:  -155112.37388105656  ,BIC:  -150019.16684657405
# componente:  100  ,tipo:  spherical  ,random:  100  ,AIC:  -155380.93207287873  ,BIC:  -150287.72503839622
# El promedio es igual a :
# AIC:
# -154216.2627796363
# BIC:
# -151407.77450352986

# %% [markdown]
# El mejor resultado obtenido por GMM emplea el escalizador Min-Max, al igual que el mejor resultado de HBDSCAN pero este emplea las 6 componentes originales de la información. Los hiperparámetros seleccionados se muestran a continuación. Nótese que el puntaje de silueta obtenido por esta solución es increíblemente bajo, pero tanto el AIC como el BIC cuentan con valores bastante pequeños, indicando un buen modelo.

# %%
gm = GaussianMixture(n_components=20, random_state=1, covariance_type='full').fit(xm)
labelsgm=gm.predict(xm)
print("Silueta")
print(silhouette_score(xm, labelsgm, metric='euclidean'))
print("AIC")
print(gm.aic(xm))
print("BIC")
print(gm.bic(xm))
# Out:
# Silueta
# -0.16992076369613038
# AIC
# -210000.11767237808
# BIC
# -206436.7850913071

# %% [markdown]
# El número de clusters encontrado por GMM es de 20. Nótese que los 8 primeros clusters son los que contienen la gran mayoría de las muestras. A continuación se muestra la gráfica que contiene la representación de los clusters.

# %%
print("Número de clusters")
pd.Series(labelsgm).value_counts()
# Out:
# Número de clusters
# 6     1227
# 2      807
# 15     640
# 19     408
# 1      307
# 13     262
# 12     203
# 5      167
# 11      89
# 10      80
# 3       34
# 0       32
# 16      21
# 18      18
# 14      17
# 9        7
# 7        6
# 4        6
# 17       3
# 8        1
# dtype: int64

# %%
model = visual.fit(xm)
projected = model.transform(xm)
plt.scatter(projected[:, 0], projected[:, 1],alpha=0.5,c=labelsgm)
plt.xlabel('componente 1')
plt.ylabel('componente 2')
# Out:
# Text(0, 0.5, 'componente 2')

# %% [markdown]
# Para facilitar la observación de la información, en la próxima gráfica se muestra la representación de los 4 clusters que mayor cantidad de muestras tienen.

# %%
a=labelsgm.copy()
np.putmask(a, a!=6 , -1)
b=labelsgm.copy()
np.putmask(b, b!=2 , -1)
c=labelsgm.copy()
np.putmask(c, c!=15 , -1)
d=labelsgm.copy()
np.putmask(d, d!=19 , -1)

# %%
fig, ax = plt.subplots(2, 2, sharey = True)
ax[0,0].scatter(projected[:, 0], projected[:, 1],alpha=0.5,c=a)
ax[0,0].set_xlabel('componente 1')
ax[0,0].set_ylabel('componente 2')

ax[0,1].scatter(projected[:, 0], projected[:, 1],alpha=0.5,c=b)
ax[0,1].set_xlabel('componente 1')
ax[0,1].set_ylabel('componente 2')

ax[1,0].scatter(projected[:, 0], projected[:, 1],alpha=0.5,c=c)
ax[1,0].set_xlabel('componente 1')
ax[1,0].set_ylabel('componente 2')

ax[1,1].scatter(projected[:, 0], projected[:, 1],alpha=0.5,c=d)
ax[1,1].set_xlabel('componente 1')
ax[1,1].set_ylabel('componente 2')

plt.show()

# %% [markdown]
# # Resultados
# En esta sección se planea analizar los resultados de los clusters producto de ambas técnicas. Como primera medida, se transforman los labels de los países de vuelta a string, además de los tipos de productos para facilitar la analizabilidad.

# %%
Xr=X.replace({'Pais':DicCountry})
dicProducto = {0 : 'impopular', 1 : 'medio', 2 : 'popular' }
Xr=Xr.replace({'Tipo':dicProducto})
Xr
# Out:
#       Frecuencia  Recencia    Dinero            Pais     Tipo  Productos
# 0              1       325  77183.60  United Kingdom  popular      74215
# 1            182         1   4310.00         Iceland  popular       2458
# 2             31        74   1797.24         Finland  popular       2341
# 3             73        18   1757.55           Italy  popular        631
# 4             17       309    334.40          Norway    medio        197
# ...          ...       ...       ...             ...      ...        ...
# 4330          10       277    180.60  United Kingdom  popular         45
# 4331           7       180     80.82  United Kingdom  popular         54
# 4332          12         7    178.05  United Kingdom  popular        103
# 4333         756         3   2094.88  United Kingdom  popular       1397
# 4334          70        42   1837.28  United Kingdom  popular       1586
#
# [4335 rows x 6 columns]

# %% [markdown]
# ## Clusters de HBDSCAN
#
# A continuación se caracteriza el cliente promedio de cada uno de los clusters con base en el promedio de las características de estos.

# %%
Xr.loc[:, ['HDBSCAN']]=labelshc
groups = Xr.groupby(Xr.HDBSCAN)
cluster0 = groups.get_group(0)
cluster1 = groups.get_group(1)
cluster2 = groups.get_group(2)

# %%
frec=[]
Rec=[]
Din=[]
Prod=[]

#Promedio cluster 0
frec.append(cluster0.loc[:, ['Frecuencia']].mean().Frecuencia)
Rec.append(cluster0.loc[:, ['Recencia']].mean().Recencia)
Din.append(cluster0.loc[:, ['Dinero']].mean().Dinero)
Prod.append(cluster0.loc[:, ['Productos']].mean().Productos)
#Promedio cluster 1
frec.append(cluster1.loc[:, ['Frecuencia']].mean().Frecuencia)
Rec.append(cluster1.loc[:, ['Recencia']].mean().Recencia)
Din.append(cluster1.loc[:, ['Dinero']].mean().Dinero)
Prod.append(cluster1.loc[:, ['Productos']].mean().Productos)
#Promedio cluster 2
frec.append(cluster2.loc[:, ['Frecuencia']].mean().Frecuencia)
Rec.append(cluster2.loc[:, ['Recencia']].mean().Recencia)
Din.append(cluster2.loc[:, ['Dinero']].mean().Dinero)
Prod.append(cluster2.loc[:, ['Productos']].mean().Productos)

# %%
numero_de_grupos = len(frec)
indice_barras = np.arange(numero_de_grupos)
ancho_barras =0.18
 
plt.bar(indice_barras, frec, width=ancho_barras, label='Frecuencia')
plt.bar(indice_barras + ancho_barras, Rec, width=ancho_barras, label='Recencia')
plt.bar(indice_barras + 2*ancho_barras, Din, width=ancho_barras, label='Dinero')
plt.bar(indice_barras + 3*ancho_barras, Prod, width=ancho_barras, label='Productos')
plt.legend(loc='best')
## Indicadores en el eje x
plt.xticks(indice_barras + ancho_barras, ['Cluster 0','Cluster 1', 'Cluster 2'])
 
plt.ylabel('Valor')
plt.xlabel('Atributo')
plt.title('Comparación de atributos')
 
plt.show()

# %% [markdown]
# En el gráfico anterior se pueden observar la frecuencia, recencia, dinero producido y total de productos comprados; en promedio por cada cluster. Como se puede observar el cluster 2 esta compuesto por los clientes más valiosos, estos son los que producen más dinero por mucho, compran la mayor cantidad de productos, tienen la mayor frecuencia y menor recencia. Este cluster está constituido por clientes que compran en grandes volumenes de productos. En cambio,  el cluster 1 es inferior al cluster 2 por mas de la mitad del valor de este, sus caractrísticas concuerdan más con clientes que compran volumenes medios a bajos de productos. Finalmente el cluster 0 está ligado a compradores esporadicos, dado la baja frecuencia y poca cantidad de producto comprado.

# %%
TipoP0=(cluster0['Tipo'].value_counts()/cluster0['Tipo'].count())*100
TipoP1=(cluster1['Tipo'].value_counts()/cluster1['Tipo'].count())*100
TipoP2=(cluster2['Tipo'].value_counts()/cluster2['Tipo'].count())*100
PaisP0=(cluster0['Pais'].value_counts()/cluster0['Pais'].count())*100
PaisP1=(cluster1['Pais'].value_counts()/cluster1['Pais'].count())*100
PaisP1=pd.DataFrame(PaisP1).reset_index()
PaisP1=PaisP1[PaisP1['index']=='United Kingdom']
PaisP1=PaisP1.append({'index':'Otros' , 'Pais':5.919662}, ignore_index=True)
PaisP2=(cluster2['Pais'].value_counts()/cluster2['Pais'].count())*100
PaisP2=pd.DataFrame(PaisP2).reset_index()
PaisP2=PaisP2[PaisP2['index']=='United Kingdom']
PaisP2=PaisP2.append({'index':'Otros' , 'Pais':9.981757}, ignore_index=True)

# %% [markdown]
# Las gráficas a continuación muestran el porcentaje de país de origen y el tipo de producto que prefieren realizar sus compras. En resumen se puede comprobar como cada cluster se encuentra definido prácticamente por el tipo de producto.

# %%
fig = plt.figure(figsize=(5,7))
ax1 = fig.add_axes([.1, .1, .8, .8], aspect=1)
ax1.pie(PaisP0, labels=PaisP0.index, autopct='%1.1f%%')
ax2 = fig.add_axes([.65, .65, .3, .3], aspect=1)  
ax2.pie(TipoP0, labels=TipoP0.index, radius=.8)  
plt.title("Cluster 0\n" + "Promedio del tipo de producto y país de origen", bbox={'facecolor':'0.8', 'pad':5})
plt.show()

# %%
fig = plt.figure(figsize=(5,7))
ax1 = fig.add_axes([.1, .1, .8, .8], aspect=1)
ax1.pie(PaisP1.Pais, labels=PaisP1['index'], autopct='%1.1f%%')
ax2 = fig.add_axes([.65, .65, .3, .3], aspect=1)  
ax2.pie(TipoP1, labels=TipoP1.index, radius=.8)  
plt.title("Cluster 1\n" + "Promedio del tipo de producto y país de origen", bbox={'facecolor':'0.8', 'pad':5})
plt.show()

# %%
fig = plt.figure(figsize=(5,7))
ax1 = fig.add_axes([.1, .1, .8, .8], aspect=1)
ax1.pie(PaisP2.Pais, labels=PaisP2['index'], autopct='%1.1f%%')
ax2 = fig.add_axes([.65, .65, .3, .3], aspect=1)  
ax2.pie(TipoP2, labels=TipoP2.index, radius=.8)  
plt.title("Cluster 2\n" + "Promedio del tipo de producto y país de origen", bbox={'facecolor':'0.8', 'pad':5})
plt.show()

# %% [markdown]
# ## Clusters de GMM
#
# Para el análisis de los clusters de GMM se usará como marco de referencia los clusters encontrados por HBDSCAN. De forma que se dividirán de acuerdo a los clusters de mayor tamaño dentro del cluster 2 de HBDSCAN rebautizado como cluster de clientes de gran volumen. No se considera el cluster 1, dado que este es explicado casí en su totalidad por el cluster 19 de GMM, por lo que los resultados son aproximadamente los mismos; ni el cluster 0, ya que este corresponde a ventas esporadicas. Para facilitar el análisis se emplean los 5 clusters de mayor tamaño dentro del cluster de clientes de gran volumen que es de especial interés para la tienda. Estos son los clusters: 6, 2, 15, 1 y 13.

# %%
Xr.loc[:, ['GMM']]=labelsgm
groups = Xr.groupby(Xr.GMM)
cluster13 = groups.get_group(13)
cluster1 = groups.get_group(1)
cluster15 = groups.get_group(15)
cluster2 = groups.get_group(2)
cluster6 = groups.get_group(6)

# %%
frec=[]
Rec=[]
Din=[]
Prod=[]

#Promedio cluster 13
frec.append(cluster13.loc[:, ['Frecuencia']].mean().Frecuencia)
Rec.append(cluster13.loc[:, ['Recencia']].mean().Recencia)
Din.append(cluster13.loc[:, ['Dinero']].mean().Dinero)
Prod.append(cluster13.loc[:, ['Productos']].mean().Productos)
#Promedio cluster 1
frec.append(cluster1.loc[:, ['Frecuencia']].mean().Frecuencia)
Rec.append(cluster1.loc[:, ['Recencia']].mean().Recencia)
Din.append(cluster1.loc[:, ['Dinero']].mean().Dinero)
Prod.append(cluster1.loc[:, ['Productos']].mean().Productos)
#Promedio cluster 15
frec.append(cluster15.loc[:, ['Frecuencia']].mean().Frecuencia)
Rec.append(cluster15.loc[:, ['Recencia']].mean().Recencia)
Din.append(cluster15.loc[:, ['Dinero']].mean().Dinero)
Prod.append(cluster15.loc[:, ['Productos']].mean().Productos)
#Promedio cluster 2
frec.append(cluster2.loc[:, ['Frecuencia']].mean().Frecuencia)
Rec.append(cluster2.loc[:, ['Recencia']].mean().Recencia)
Din.append(cluster2.loc[:, ['Dinero']].mean().Dinero)
Prod.append(cluster2.loc[:, ['Productos']].mean().Productos)
#Promedio cluster 6
frec.append(cluster6.loc[:, ['Frecuencia']].mean().Frecuencia)
Rec.append(cluster6.loc[:, ['Recencia']].mean().Recencia)
Din.append(cluster6.loc[:, ['Dinero']].mean().Dinero)
Prod.append(cluster6.loc[:, ['Productos']].mean().Productos)

# %%
numero_de_grupos = len(frec)
indice_barras = np.arange(numero_de_grupos)
ancho_barras =0.18
 
plt.bar(indice_barras, frec, width=ancho_barras, label='Frecuencia')
plt.bar(indice_barras + ancho_barras, Rec, width=ancho_barras, label='Recencia')
plt.bar(indice_barras + 2*ancho_barras, Din, width=ancho_barras, label='Dinero')
plt.bar(indice_barras + 3*ancho_barras, Prod, width=ancho_barras, label='Productos')
plt.legend(loc='best')
## Indicadores en el eje x
plt.xticks(indice_barras + ancho_barras, ['Cluster 13','Cluster 1', 'Cluster 15 ', 'Cluster 2 ','Cluster 6'])
 
plt.ylabel('Valor')
plt.xlabel('Atributo')
plt.title('Comparación de atributos')
 
plt.show()

# %% [markdown]
# La gráfica anterior corresponde a el promedio de los 5 clusters más importantes dentro de los clientes de grandes volumenes. Estos se encuentran ordenados de los clusters menor tamaño, correspondiente al 13, al cluster de mayor tamaño correspondiente al cluster 6. Se puede observar que el cluster 1 pese a ser el penúltimo cluster en tamaño, su participación en cada una de las métricas sea tan favorable, su desemepeño sobrepasa a sus contrapartes por mucho, el cluster 15 pese a tener el segundo lugar en el escalafón, tiene una diferencia muy marcada con respecto al cluster 1; aún así el cluster 15 tiene características bastante favorables si se compara con los otros 3 clusters restantes.

# %%
PaisP13=(cluster13['Pais'].value_counts()/cluster13['Pais'].count())*100
PaisP13=pd.DataFrame(PaisP13).reset_index()
PaisP13=PaisP13[PaisP13['Pais']>=3]
PaisP13=PaisP13.append({'index':'Otros' , 'Pais':100-PaisP13.Pais.sum()}, ignore_index=True)
PaisP1=(cluster1['Pais'].value_counts()/cluster1['Pais'].count())*100
PaisP15=(cluster15['Pais'].value_counts()/cluster15['Pais'].count())*100
PaisP2=(cluster2['Pais'].value_counts()/cluster2['Pais'].count())*100
PaisP6=(cluster6['Pais'].value_counts()/cluster6['Pais'].count())*100

# %% [markdown]
# En cuanto al análisis del país de procedencia de los clusters se puede apreciar en los gráficos a continuación que la mayoría de los clusters tienen una presencia 100% en Reino Unido; sin embargo, el cluster 13 sobresale por no tener ningún cliente de Reino Unido, en vez de ello este tiene presencia internacional, se tiene una fuente presencia en Europa donde Alemania, Francia y España son los países donde se relizan más compras. Aún así se tiene presencia en algunos países de Asía y America. En la mayoría la paricipación es tan baja que se encuentra etiquetado en la región de Otros pero, el hecho de tener un alcance tan amplio puede ser una oportunidad de negocio interesante.

# %%
plt.style.use('ggplot')
fig, axes = plt.subplots(1,2, figsize=(12,5))

axes[0].pie(PaisP13.Pais, labels=PaisP13['index'])
axes[0].set(ylabel='', title='Cluster 13', aspect='equal')

axes[1].pie(PaisP1, labels=PaisP1.index)
axes[1].set(ylabel='', title='Cluster 1, 15, 2, 6', aspect='equal')

#axes[2].pie(PaisP15, labels=PaisP15.index)
#axes[2].set(ylabel='', title='Cluster 15', aspect='equal')

#axes[3].pie(PaisP2, labels=PaisP2.index)
#axes[3].set(ylabel='', title='Cluster 2', aspect='equal')

#axes[4].pie(PaisP6, labels=PaisP6.index)
#axes[4].set(ylabel='', title='Cluster 6', aspect='equal')


axes[0].legend(bbox_to_anchor=(0, 1))
fig.savefig('plot.pdf')
plt.show()

# %% [markdown]
# # Discusión
#
# En esta sección se discuten los resultados de los barridos de características sobre ambos métodos.

# %% [markdown]
# ## Análisis de PCA
#
# Para analizar el comportamiento de los modelos con respecto al número de componentes usado se analiza tanto el promedio obtenido por cada barrido de hiperparámetros como el mejor resultado obtenido en cada uno por cada métrica empleada.

# %%
PHDBSCAN6=[0.03675235739921913,0.021744609152629893,0.04259129057688213]
PHDBSCAN4=[0.054396025967151686,0.01333089885971043,0.043667906985277935]
PHDBSCAN3=[0.006461210060429141,0.01734171014386148,0.034483083856617316]
PHDBSCAN2=[0.05030777734056472,0.02700914917374678,0.01423569917915623]

RHDBSCAN6=[0.05055804307738585,0.07896476406062745,0.1360085959308536]
RHDBSCAN4=[0.218974770249996,0.07516245314094526,0.1522877478085598]
RHDBSCAN3=[0.1291696318050703,0.08418518086624774,0.39023165717098096]
RHDBSCAN2=[0.4415612235947517,0.2951206021750694,0.21684932504723042]


numero_de_grupos = len(PHDBSCAN6)
indice_barras = np.arange(numero_de_grupos)
ancho_barras =0.18
 
plt.subplot(1, 2, 1)
plt.bar(indice_barras, PHDBSCAN6, width=ancho_barras, label='6 comp.')
plt.bar(indice_barras + ancho_barras, PHDBSCAN4, width=ancho_barras, label='4 comp.')
plt.bar(indice_barras + 2*ancho_barras, PHDBSCAN3, width=ancho_barras, label='3 comp.')
plt.bar(indice_barras + 3*ancho_barras, PHDBSCAN2, width=ancho_barras, label='2 comp.')
plt.legend(loc='best')
## Indicadores en el eje x
plt.xticks(indice_barras + ancho_barras, ['Min-max','Robusto', 'Estándar'])
 
plt.ylabel('DBCV')
plt.xlabel('Escalizador')
plt.title('Promedio')

plt.subplot(1, 2, 2)
plt.bar(indice_barras, RHDBSCAN6, width=ancho_barras, label='6 comp.')
plt.bar(indice_barras + ancho_barras, RHDBSCAN4, width=ancho_barras, label='4 comp.')
plt.bar(indice_barras + 2*ancho_barras, RHDBSCAN3, width=ancho_barras, label='3 comp.')
plt.bar(indice_barras + 3*ancho_barras, RHDBSCAN2, width=ancho_barras, label='2 comp.')
plt.legend(loc='best')
## Indicadores en el eje x
plt.xticks(indice_barras + ancho_barras, ['Min-max','Robusto', 'Estándar'])
 
plt.ylabel('DBCV')
plt.xlabel('Escalizador')
plt.title('Mejor resultado')
 
plt.show()

# %% [markdown]
# Con respecto a la imagen anterior se puede observar que no existe una respuesta única respecto al número de componentes ideal, ya que esto depende del escalizador utilizado. El escalizador robusto se beneficia de la reducción dimensional, mientras el escalizador estándar empobrece su desempeño conforme se emplean menos dimensiones. El escalizador Min-Max no parece tener efectos consistentes.
#
# Comparando el uso de los 6 componentes originales con respecto a sus homólogos con menos dimensiones, se puede concluir que estos producen modelos más débiles, esto es interesante dado que este efecto no se aprecia cuando se emplea el promedio como referencia, sino los mejores resultados de cada uno.

# %%
PAIC6=[-154216.2627796363,8033.257882067427,-39772.730139512525]
PAIC4=[-87045.18090189114,22566.07377816242,-5174.395888426204]
PAIC3=[-84907.7629637952,19545.573986743446,3947.6664818937297]
PAIC2=[-59326.30148867184,13139.68394117537,12424.304341634863]

RAIC6=[-212473.58933081295,-76163.874203746,-115096.68268263276]
RAIC4=[-212369.17893311923,-19124.692670281394,-115096.68268263276]
RAIC3=[-101560.8873336188,-13695.51385258649,-22585.486031795554]
RAIC2=[-68203.9322260782,-5385.978559481048,7575.931911362875]

numero_de_grupos = len(PAIC6)
indice_barras = np.arange(numero_de_grupos)
ancho_barras =0.18
 
plt.subplot(1, 2, 1)
plt.bar(indice_barras, PAIC6 , width=ancho_barras, label='6 comp.')
plt.bar(indice_barras + ancho_barras, PAIC4, width=ancho_barras, label='4 comp.')
plt.bar(indice_barras + 2*ancho_barras, PAIC3, width=ancho_barras, label='3 comp.')
plt.bar(indice_barras + 3*ancho_barras, PAIC2, width=ancho_barras, label='2 comp.')
plt.legend(loc='best')
## Indicadores en el eje x
plt.xticks(indice_barras + ancho_barras, ['Min-max','Robusto', 'Estándar'])
 
plt.ylabel('AIC')
plt.xlabel('Escalizador')
plt.title('Promedio')
 

plt.subplot(1, 2, 2)
plt.bar(indice_barras, RAIC6 , width=ancho_barras, label='6 comp.')
plt.bar(indice_barras + ancho_barras, RAIC4, width=ancho_barras, label='4 comp.')
plt.bar(indice_barras + 2*ancho_barras, RAIC3, width=ancho_barras, label='3 comp.')
plt.bar(indice_barras + 3*ancho_barras, RAIC2, width=ancho_barras, label='2 comp.')
plt.legend(loc='best')
## Indicadores en el eje x
plt.xticks(indice_barras + ancho_barras, ['Min-max','Robusto', 'Estándar'])
 
plt.ylabel('AIC')
plt.xlabel('Escalizador')
plt.title('Mejor resultado')

plt.show()

# %% [markdown]
# El comportamiento en la gráfica del AIC evidencia que los resultados son similares a los obtenidos por el DBCV, sin embargo en esta se puede observar como el Min-Max parece disminuir su desempeño conforme se reduce el número de componentes utilizado. Además en esta imagen se puede observar como los barridos de 6 componentes parecen tener mejor puntaje a sus homólogos con menor dimensiones. Este comportamiento se puede extender al BIC dada su estrecha relación con el AIC.

# %%
PBIC6=[-151407.77450352986,10841.74615817391,-36964.24186340604]
PBIC4=[-85297.24621822775,24314.00846182582,-3426.4612047628043]
PBIC3=[-83613.2129488772,20840.12400166145,5242.216496811735 ]
PBIC2=[-58433.87472418179, 14032.11070566542,13316.731106124913]

RBIC6=[-207139.10696273786,-58321.71339083422,-106537.56384691224]
RBIC4=[-125522.77005368887,-9569.351813348645,-53360.319965064584]
RBIC3=[-97914.04901185188,-7484.948287526306,-18142.923125286947]
RBIC2=[-66300.61666813653,-1567.6669028414772,9622.509520089663]

numero_de_grupos = len(PBIC6)
indice_barras = np.arange(numero_de_grupos)
ancho_barras =0.18

plt.subplot(1, 2, 1) 
plt.bar(indice_barras, PBIC6, width=ancho_barras, label='6 comp.')
plt.bar(indice_barras + ancho_barras, PBIC4, width=ancho_barras, label='4 comp.')
plt.bar(indice_barras + 2*ancho_barras, PBIC3, width=ancho_barras, label='3 comp.')
plt.bar(indice_barras + 3*ancho_barras, PBIC2, width=ancho_barras, label='2 comp.')
plt.legend(loc='best')
## Indicadores en el eje x
plt.xticks(indice_barras + ancho_barras, ['Min-max','Robusto', 'Estándar'])
 
plt.ylabel('BIC')
plt.xlabel('Escalizador')
plt.title('Promedio')

plt.subplot(1, 2, 2) 
plt.bar(indice_barras, RBIC6, width=ancho_barras, label='6 comp.')
plt.bar(indice_barras + ancho_barras, RBIC4, width=ancho_barras, label='4 comp.')
plt.bar(indice_barras + 2*ancho_barras, RBIC3, width=ancho_barras, label='3 comp.')
plt.bar(indice_barras + 3*ancho_barras, RBIC2, width=ancho_barras, label='2 comp.')
plt.legend(loc='best')
## Indicadores en el eje x
plt.xticks(indice_barras + ancho_barras, ['Min-max','Robusto', 'Estándar'])
 
plt.ylabel('BIC')
plt.xlabel('Escalizador')
plt.title('Mejor resultado')
 
plt.show()

# %% [markdown]
# ## Barrido de hiperparámetros
#
# A continuación se presenta el barrido únicamente de hiperparámetros teniendo en cuenta el promedio de las métricas de interés en el barrido asociado al modelo seleccionado.

# %% [markdown]
# ### HBDSCAN

# %%
def graficarHiper(x,y,paramName):
  plt.plot(x,y,"xr--",mec="b")
  plt.xlabel(paramName)
  plt.ylabel("puntaje DBCV")
  plt.show()

# %% [markdown]
# #### Muestras mínimas
#
# Este valor representa  que tan conservativo es el cluster, es decir cuantas de las muestras alrededor del cluster se debe incluir y cuanto se debe rechazar. Su valor óptimo de este se encuentra en 3, valores diferentes con lleva puntaciones inferiores

# %%
graficarHiper(min_sample,array_sample,"min_samples")

# %% [markdown]
# #### Tamaño mínimo de cluster
#
# Este es el número más pequeño de muestras que necesita un grupo para ser considerado un cluster. A partir de 30 este puntaje se mantiene estable en su puntaje máximo.

# %%
graficarHiper(min_cluster,array_cluster,"min_cluster_size")

# %% [markdown]
# #### Épsilon
# Controla la separación de los clusters dentro de la jerarquía de densidad y por ende también controla cuando los clusters deben mantenerse juntos en un solo cluster. Su puntaje óptimo se encuentra alrededor de 0.3.

# %%
graficarHiper(epsilon,array_epsilon,"epsilon")

# %% [markdown]
# #### Alfa
#
# Al igual que las muestras mínimas permite determinar que tan conservativo es el cluster aunque este es un parámetro mucho más sensible, el cual no se recomienda alterar. Aun así la variación de este no parece tener ningún efecto sobre el resultado final del modelo.

# %%
graficarHiper(alpha,array_alpha,"alpha")

# %% [markdown]
# ### GMM

# %%
def graficarHiperX2(x,yAIC,yBIC,paramName):
  fig, ax = plt.subplots()
  ax.plot(x, yAIC, label = 'AIC')
  ax.plot(x, yBIC, label = 'BIC')
  ax.legend(loc = 'upper right')
  plt.show()

# %% [markdown]
# #### Número de componentes
#
# El número de componentes es igual al número de clusters a formar. Entre mayor era este hipeparámetro mejor eran los resultados, aun así mayor número de clusters hacen la información más difícil de interpretar.

# %%
graficarHiperX2(n_componentes,array_componentesAIC,array_componentesBIC,"n_components")

# %% [markdown]
# #### Tipo de la covarianza
#
# El tipo de covarianza se distingue en cuatro categorías:
#
# *   full: Cada componente tiene su propia matriz de covarianza.
# *   tied: Los componentes comparten la misma matriz de covarianza.
# *   diag: Cada componente tiene su propia diagonal de covarianza.
# *   spherical: Cada componente tiene su propia varianza.
#
# Las covarianzas que mejor se desempeñaron fue en primer lugar full, seguido por tied. Las restantes tuvieron desempeño  mucho inferior a las previamente mencionadas.

# %%
graficarHiperX2(tipo,array_tipoAIC,array_tipoBIC,"covariance_type")

# %% [markdown]
# #### Semilla aleatoria
#
# La semilla aleatoria también se tomó como un hiperparámetro dentro del modelo. Los mejores puntajes se asocian con un valor cercano a 0. Es sorpresivo observar como este hiperparámetro podía ser decisivo en los puntajes obtenidos por el algoritmo.

# %%
graficarHiperX2(random,array_randomAIC,array_randomBIC,"random_state")

# %% [markdown]
# # Conclusiones

# %% [markdown]
# Comparando ambos métodos implementados se pueden apreciar las fortalezas y debilidades de cada uno. El método HBDSCAN es un método jerárquico basado en densidades, mientras GMM es un método plano basado en probabilidad. HBDSCAN resulta ser más intuitivo lo que resulta útil para definir o modificar parámetros, mientras que GMM no es tan intuitivo al estar basado en funciones de probabilidad, esta característica resulta ser la más importante de acuerdo a los resultados obtenidos. HBDSCAN obtuvo el resultado más obvio, aunque no deja de ser correcto, este resultado es posible obtenerlo a simple vista. En cambio, GMM fue capaz de tomar los grupos básicos y subdividirlos en 20 grupos totales de los que es posible resaltar 8 por su tamaño. Este se encuentra más cercano al resultado que se esperaba del proyecto, de forma que la capacidad de GMM de aplicar funciones de probabilidad sobre el conjunto de datos la hace una técnica más capaz dentro de este problema al no solo entender la forma del cluster, sino al caracterizar el mecanismo detrás de este. En cuanto a las debilidades de GMM se encuentra su necesidad de asignar un gran número de custers, con frecuencia se observaba un número de 20, 50 y hasta 100 clusters, donde dentro de la mayoría se encontraban un número inferior a 10 elementos. En contraste HDBSCAN solía arrojar respuestas con un número de entre 3 y 10 clusters.
#
# En cuento al uso de las métricas, el uso de BIC y AIC tuvo mejores resultados que el DBCV. En primer lugar, tener dos métricas otorga dos marcos de referencia además que las puntuaciones de estas eran más consistentes con agrupamiento de clusters de mejor calidad, mientras que en el DBCV muchas veces se necesitaba apoyarse de la gráfica para poder determinar el acabado del cluster lo cual conlleva a una perdida de objetividad sobre la elección del modelo. Aunque otra posible causa de esto es que HDBSCAN podía ser verificado observando los patrones de las gráficas, mientras que GMM no contaba con esa posibilidad.
#
# En resumidas cuentas no se considera que GMM sea una técnica superior a HDBSCAN, solo que esta se adapta más a la información y dominio del problema. HBDSCAN puede ser más útil en datasets donde exista mucha información y el ruido presente sea mucho mayor. Observando las gráficas derivadas del escalizador Min-Max, que fue el que obtuvo mejor rendimiento, se puede observar como apenas se encuentra ruido o perturbaciones sobre este.
#
# En cuanto al fenómeno encontrado, donde el escalizador determina tanto el patrón de la información, como la varianza de cada componente y el desempeño del modelo final, este fenómeno era desconocido y demuestra que este factor tiene mucho más peso del que se creía inicialmente.

# %%
fig, ax = plt.subplots(2, sharey = True, figsize=(8, 12))
ax[0].scatter(projected[:, 0], projected[:, 1],alpha=0.5,c=labelshc)
ax[0].set_xlabel('componente 1')
ax[0].set_ylabel('componente 2')

ax[1].scatter(projected[:, 0], projected[:, 1],alpha=0.5,c=labelsgm)
ax[1].set_xlabel('componente 1')
ax[1].set_ylabel('componente 2')
# Out:
# Text(0, 0.5, 'componente 2')
